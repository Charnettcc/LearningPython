# %%
import numpy

# %%
numpy.loadtxt('cleaned_data.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4250264a3415> in <module>()
# ----> 1 numpy.loadtxt('cleaned_data.csv', delimiter=',')
#
# C:\Users\Lizzie.LIZ.000\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Users\Lizzie.LIZ.000\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
# ...

# %%
import pandas

# %%
df = pandas.read_csv('cleaned_data.csv')

# %%
df
# Out:
#      #  Day  Month  Year  Plot Species Sex Weight_Value Weight_Unit  \
# 0    1   16      7  2013     2      DM   F           ##          ##
# 1    2   16      7  2013     7      DM   M           33           g
# 2    3   16      7  2013     3      DM   M           ##          ##
# 3    4   16      7  2013     1      DM   M           ##          ##
# 4    5   18      7  2013     3      DM   M           40           g
# 5    6   18      7  2013     7      DM   M           48           g
# 6    7   18      7  2013     4      DM   F           29           g
# 7    8   18      7  2013     4      DM   F           46           g
# 8    9   18      7  2013     7      DM   M           36           g
# 9   10   18      7  2013     7      DM   F           35           g
# 10  11   18      7  2013     8      DM   F           22           g
# 11  12   18      7  2013     7      DM   F           42           g
# 12  13   18      7  2013     4      DM   F           41           g
# ...

# %%
numpy.mean(df.Weight_Value[df.Sex == 'F'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Lizzie.LIZ.000\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     737         try:
# --> 738             x = float(x)
#     739         except Exception:
#
# ValueError: could not convert string to float: '##2946352242413752335048314144394041117121120118126113122107115361353914451441463537772322##1822911537128424842'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Lizzie.LIZ.000\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     740             try:
# --> 741                 x = complex(x)
#     742             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ...
